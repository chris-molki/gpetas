# %% [markdown]
# ## Inference: GP-ETAS
#
# ### Bayesian inference via sampling
# Starting the GP-ETAS sampler require a ```gpetas```
# *setup_obj* as described above. It contains everything
# you need: data, domain definition, setup variables.
#
# Load or generate a *setup_obj* as described above and
# initialize the sampler.

# %%
import gpetas
import numpy as np
import datetime
time_format = "%Y-%m-%d %H:%M:%S.%f"


# auto reload using developer version
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# #### Initialization of the sampler requires a *setup_obj* which includes *data_obj* and *domain_obj*
# In this example we load a previously generated *setup_obj*.

# %%
case_name = 'Rxxx'
print(case_name)
output_dir = './output/inference_results'
fname = output_dir+'/setup_obj_%s.all'%case_name
setup_obj = np.load(fname,allow_pickle=True)
#vars(setup_obj)
# Out:
# Rxxx

# %% [markdown]
# #### Initalization of the sampler

# %%
GS = gpetas.Gibbs_sampler.GS_ETAS(data_obj=setup_obj.data_obj, 
        setup_obj=setup_obj, 
        burnin=setup_obj.burnin,
        num_samples=setup_obj.num_iterations, 
        stat_background=False, 
        thinning=setup_obj.thinning,
        kth_sample_obj=setup_obj.kth_sample_obj, 
        case_name=setup_obj.case_name, 
        MH_proposals_offspring=setup_obj.MH_proposals_offspring, 
        MH_cov_empirical_yes=setup_obj.MH_cov_empirical_yes)
# Out:
# UPPER BOUND: lambda_star_start =  0.003394557823129252
# ===================================================
# INITIALIZATION of theta_tilde (offspring parameters)
#      spatial kernel:  Rupture Length Power Law with params: D_RL_pwl, gamma_RL_pwl, q_RL_pwl
# [K, c, p, m_alpha, D_RL_pwl, gamma_RL_pwl, q_RL_pwl, m_beta, m0]
# [2.5000000e-03 1.0000000e-02 1.2000000e+00 1.8000000e+00 5.0000000e-02
#  5.0000000e-01 2.0000000e+00 2.3977128e+00 3.5000000e+00]
# ===================================================
# START: hyper prior: self.prior_mu_upper_bound  = [0.17222638]
# START: self.alpha0                             = 1.0
# START: self.beta0                              = [5.80631154]
# START: self.prior_std_factor_upper_bound       = 1.0

# %%
# some info to the screen
import pprint
print('---------------------------------------')
print('case name                =',setup_obj.case_name)
print('---------------------------------------')
print('domain from data_obj')
pprint.pprint(vars(setup_obj.data_obj.__dict__['domain']))
print('---------------------------------------')
print('burnin                   = ',setup_obj.burnin)
print('Ksamples                 = ',setup_obj.Ksamples)
print('thinning                 = ',setup_obj.thinning)
print('Ntotal iter              = ',setup_obj.num_iterations)
print('MH_proposals_offspring   = ',setup_obj.MH_proposals_offspring)
print('MH_cov_empirical_yes     = ',setup_obj.MH_cov_empirical_yes)
print('kth_sample_obj           = ',setup_obj.kth_sample_obj)
print('---------------------------------------')
print('theta prior:                           ')
print('prior_theta_dist         =',setup_obj.prior_theta_dist)
print('prior_theta_params       =',setup_obj.prior_theta_params)
print('stable_theta_sampling    =',setup_obj.stable_theta_sampling)
# Out:
# ---------------------------------------
# case name                = Rxxx
# ---------------------------------------
# domain from data_obj
# {'T_borders_all': array([   0., 4383.]),
#  'T_borders_testing': array([3000., 4383.]),
#  'T_borders_training': array([   0., 3000.]),
#  'X_borders': array([[-120., -113.],
#        [  30.,   37.]]),
#  'X_borders_UTM_km': None,
#  'X_borders_original': array([[-120., -113.],
#        [  30.,   37.]]),
#  'm0': 3.5,
#  'time_origin': '2010-01-01 00:00:00.000000'}
# ---------------------------------------
# burnin                   =  100
# Ksamples                 =  100
# thinning                 =  10
# Ntotal iter              =  1001
# MH_proposals_offspring   =  100
# MH_cov_empirical_yes     =  None
# kth_sample_obj           =  None
# ---------------------------------------
# theta prior:
# prior_theta_dist         = gamma
# prior_theta_params       = None
# stable_theta_sampling    = yes

# %% [markdown]
# #### Start sampler

# %%
GS.sample()
# Out:
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.51
# self.hyper_prior_length_scale_factor = 0.1
# self.hyper_prior_mu_length_scale     = [0.7 0.7]
# self.hyper_prior_mu_nu0              = 5
# self.hyper_prior_length_scale_factor = 0.1
# self.hyper_prior_mu_length_scale     = [0.7 0.7]
# self.hyper_prior_mu_nu0              = 5
# ==== sampling cov params====
# BG self.iteration= 0
# cov params= [5.0, array([0.37814954, 0.37814954])]
# iter=  1 Current lambda_star [0.00596845] M= 285 N0= 617
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.44
# ==== sampling cov params====
# BG self.iteration= 1
# cov params= [5.0, array([0.37814954, 0.37814954])]
# iter=  2 Current lambda_star [0.0068454] M= 530 N0= 458
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.48
# ==== sampling cov params====
# BG self.iteration= 2
# cov params= [5.0, array([0.37814954, 0.37814954])]
# iter=  3 Current lambda_star [0.00759282] M= 677 N0= 431
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.47
# ==== sampling cov params====
# BG self.iteration= 3
# cov params= [5.0, array([0.37814954, 0.37814954])]
# iter=  4 Current lambda_star [0.0076455] M= 781 N0= 413
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.52
# ==== sampling cov params====
# BG self.iteration= 4
# cov params= [5.0, array([0.37814954, 0.37814954])]
# iter=  5 Current lambda_star [0.00783007] M= 792 N0= 365
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.52
# ==== sampling cov params====
# BG self.iteration= 5
# cov params= [5.0, array([0.37814954, 0.37814954])]
# iter=  6 Current lambda_star [0.00800793] M= 827 N0= 350
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.41
# ==== sampling cov params====
# BG self.iteration= 6
# cov params= [5.0, array([0.37814954, 0.37814954])]
# iter=  7 Current lambda_star [0.00763063] M= 869 N0= 306
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.41
# ==== sampling cov params====
# BG self.iteration= 7
# cov params= [5.0, array([0.37814954, 0.37814954])]
# iter=  8 Current lambda_star [0.00693754] M= 762 N0= 280
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.2
# ==== sampling cov params====
# BG self.iteration= 8
# cov params= [5.0, array([0.37814954, 0.37814954])]
# iter=  9 Current lambda_star [0.00660159] M= 717 N0= 266
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.26
# ==== sampling cov params====
# BG self.iteration= 9
# cov params= [5.0, array([0.37814954, 0.37814954])]
# iter=  10 Current lambda_star [0.00646246] M= 696 N0= 254
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.21
# ==== sampling cov params====
# BG self.iteration= 10
# cov params= [5.0, array([0.37814954, 0.37814954])]
# iter=  11 Current lambda_star [0.00616179] M= 703 N0= 254
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.27
# ==== sampling cov params====
# BG self.iteration= 11
# cov params= [5.0, array([0.37814954, 0.37814954])]
# iter=  12 Current lambda_star [0.0066561] M= 684 N0= 240
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.28
# ==== sampling cov params====
# BG self.iteration= 12
# cov params= [5.0, array([0.37814954, 0.37814954])]
# iter=  13 Current lambda_star [0.00650915] M= 738 N0= 251
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.3
# ==== sampling cov params====
# BG self.iteration= 13
# cov params= [5.0, array([0.37814954, 0.37814954])]
# iter=  14 Current lambda_star [0.00639436] M= 692 N0= 241
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.22
# ==== sampling cov params====
# BG self.iteration= 14
# cov params= [5.0, array([0.37814954, 0.37814954])]
# iter=  15 Current lambda_star [0.00595308] M= 686 N0= 243
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.2
# ==== sampling cov params====
# BG self.iteration= 15
# cov params= [5.0, array([0.37814954, 0.37814954])]
# iter=  16 Current lambda_star [0.00625014] M= 650 N0= 238
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.23
# ==== sampling cov params====
# BG self.iteration= 16
# cov params= [5.0, array([0.37814954, 0.37814954])]
# iter=  17 Current lambda_star [0.00627396] M= 707 N0= 228
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.22
# ==== sampling cov params====
# BG self.iteration= 17
# cov params= [5.0, array([0.37814954, 0.37814954])]
# iter=  18 Current lambda_star [0.0066048] M= 679 N0= 238
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.16
# ==== sampling cov params====
# BG self.iteration= 18
# cov params= [5.0, array([0.37814954, 0.37814954])]
# iter=  19 Current lambda_star [0.0063142] M= 696 N0= 239
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.23
# ==== sampling cov params====
# BG self.iteration= 19
# cov params= [5.0, array([0.37814954, 0.37814954])]
# iter=  20 Current lambda_star [0.0066978] M= 731 N0= 246
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.21
# ==== sampling cov params====
# BG self.iteration= 20
# cov params= [5.0, array([0.37814954, 0.37814954])]
# iter=  21 Current lambda_star [0.00636946] M= 676 N0= 229
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.11
# ==== sampling cov params====
# BG self.iteration= 21
# cov params= [5.0, array([0.37814954, 0.37814954])]
# iter=  22 Current lambda_star [0.00603747] M= 685 N0= 238
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.17
# ==== sampling cov params====
# BG self.iteration= 22
# cov params= [5.0, array([0.37814954, 0.37814954])]
# iter=  23 Current lambda_star [0.00651678] M= 667 N0= 232
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.1
# ==== sampling cov params====
# BG self.iteration= 23
# cov params= [5.0, array([0.37814954, 0.37814954])]
# iter=  24 Current lambda_star [0.00631908] M= 738 N0= 230
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.16
# ==== sampling cov params====
# BG self.iteration= 24
# cov params= [5.0, array([0.37814954, 0.37814954])]
# iter=  25 Current lambda_star [0.00629514] M= 707 N0= 218
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.07
# ==== sampling cov params====
# BG self.iteration= 25
# cov params= [array([5.08476102]), array([0.38270105, 0.37901761])]
# iter=  26 Current lambda_star [0.0061637] M= 681 N0= 228
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.14
# ==== sampling cov params====
# BG self.iteration= 26
# cov params= [array([5.08476102]), array([0.38270105, 0.37901761])]
# iter=  27 Current lambda_star [0.00614887] M= 686 N0= 227
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.12
# ==== sampling cov params====
# BG self.iteration= 27
# cov params= [array([4.80193731]), array([0.38543693, 0.3837357 ])]
# iter=  28 Current lambda_star [0.0056087] M= 631 N0= 227
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.18
# ==== sampling cov params====
# BG self.iteration= 28
# cov params= [array([4.80193731]), array([0.38543693, 0.3837357 ])]
# iter=  29 Current lambda_star [0.00589275] M= 611 N0= 226
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.16
# ==== sampling cov params====
# BG self.iteration= 29
# cov params= [array([4.80193731]), array([0.38543693, 0.3837357 ])]
# iter=  30 Current lambda_star [0.00624424] M= 677 N0= 223
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.15
# ==== sampling cov params====
# BG self.iteration= 30
# cov params= [array([4.80193731]), array([0.38543693, 0.3837357 ])]
# iter=  31 Current lambda_star [0.00620442] M= 677 N0= 228
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.17
# ==== sampling cov params====
# BG self.iteration= 31
# cov params= [array([4.80193731]), array([0.38543693, 0.3837357 ])]
# iter=  32 Current lambda_star [0.00615298] M= 696 N0= 217
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.13
# ==== sampling cov params====
# BG self.iteration= 32
# cov params= [array([4.80193731]), array([0.38543693, 0.3837357 ])]
# iter=  33 Current lambda_star [0.00589778] M= 664 N0= 225
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.05
# ==== sampling cov params====
# BG self.iteration= 33
# cov params= [array([4.80193731]), array([0.38543693, 0.3837357 ])]
# iter=  34 Current lambda_star [0.00556189] M= 643 N0= 214
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.15
# ==== sampling cov params====
# BG self.iteration= 34
# cov params= [array([4.80193731]), array([0.38543693, 0.3837357 ])]
# iter=  35 Current lambda_star [0.00569284] M= 602 N0= 204
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.1
# ==== sampling cov params====
# BG self.iteration= 35
# cov params= [array([4.80193731]), array([0.38543693, 0.3837357 ])]
# iter=  36 Current lambda_star [0.00576985] M= 615 N0= 219
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.17
# ==== sampling cov params====
# BG self.iteration= 36
# cov params= [array([4.80193731]), array([0.38543693, 0.3837357 ])]
# iter=  37 Current lambda_star [0.00559644] M= 602 N0= 222
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.15
# ==== sampling cov params====
# BG self.iteration= 37
# cov params= [array([4.80193731]), array([0.38543693, 0.3837357 ])]
# iter=  38 Current lambda_star [0.00534375] M= 618 N0= 230
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.22
# ==== sampling cov params====
# BG self.iteration= 38
# cov params= [array([4.80193731]), array([0.38543693, 0.3837357 ])]
# iter=  39 Current lambda_star [0.0054125] M= 571 N0= 220
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.13
# ==== sampling cov params====
# BG self.iteration= 39
# cov params= [array([4.80193731]), array([0.38543693, 0.3837357 ])]
# iter=  40 Current lambda_star [0.0051845] M= 556 N0= 230
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.12
# ==== sampling cov params====
# BG self.iteration= 40
# cov params= [array([4.80193731]), array([0.38543693, 0.3837357 ])]
# iter=  41 Current lambda_star [0.00561736] M= 536 N0= 223
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.21
# ==== sampling cov params====
# BG self.iteration= 41
# cov params= [array([4.80193731]), array([0.38543693, 0.3837357 ])]
# iter=  42 Current lambda_star [0.0056259] M= 621 N0= 226
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.17
# ==== sampling cov params====
# BG self.iteration= 42
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  43 Current lambda_star [0.00549273] M= 596 N0= 223
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.13
# ==== sampling cov params====
# BG self.iteration= 43
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  44 Current lambda_star [0.00545832] M= 581 N0= 228
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.17
# ==== sampling cov params====
# BG self.iteration= 44
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  45 Current lambda_star [0.00539021] M= 592 N0= 206
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.08
# ==== sampling cov params====
# BG self.iteration= 45
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  46 Current lambda_star [0.00519123] M= 547 N0= 214
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.15
# ==== sampling cov params====
# BG self.iteration= 46
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  47 Current lambda_star [0.0052233] M= 552 N0= 229
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.17
# ==== sampling cov params====
# BG self.iteration= 47
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  48 Current lambda_star [0.00517407] M= 549 N0= 217
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.23
# ==== sampling cov params====
# BG self.iteration= 48
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  49 Current lambda_star [0.00561746] M= 569 N0= 222
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.27
# ==== sampling cov params====
# BG self.iteration= 49
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  50 Current lambda_star [0.00572174] M= 625 N0= 231
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.13
# ==== sampling cov params====
# BG self.iteration= 50
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  51 Current lambda_star [0.00538251] M= 595 N0= 227
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.2
# ==== sampling cov params====
# BG self.iteration= 51
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  52 Current lambda_star [0.00570929] M= 542 N0= 231
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.21
# ==== sampling cov params====
# BG self.iteration= 52
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  53 Current lambda_star [0.00553546] M= 586 N0= 224
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.19
# ==== sampling cov params====
# BG self.iteration= 53
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  54 Current lambda_star [0.00549095] M= 606 N0= 222
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.2
# ==== sampling cov params====
# BG self.iteration= 54
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  55 Current lambda_star [0.00545248] M= 570 N0= 225
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.21
# ==== sampling cov params====
# BG self.iteration= 55
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  56 Current lambda_star [0.00508545] M= 538 N0= 225
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.15
# ==== sampling cov params====
# BG self.iteration= 56
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  57 Current lambda_star [0.00460629] M= 518 N0= 217
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.19
# ==== sampling cov params====
# BG self.iteration= 57
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  58 Current lambda_star [0.00468553] M= 482 N0= 232
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.1
# ==== sampling cov params====
# BG self.iteration= 58
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  59 Current lambda_star [0.00465024] M= 460 N0= 219
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.15
# ==== sampling cov params====
# BG self.iteration= 59
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  60 Current lambda_star [0.00498049] M= 489 N0= 238
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.21
# ==== sampling cov params====
# BG self.iteration= 60
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  61 Current lambda_star [0.00481563] M= 528 N0= 229
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.15
# ==== sampling cov params====
# BG self.iteration= 61
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  62 Current lambda_star [0.00456975] M= 466 N0= 215
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.2
# ==== sampling cov params====
# BG self.iteration= 62
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  63 Current lambda_star [0.00477174] M= 487 N0= 226
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.19
# ==== sampling cov params====
# BG self.iteration= 63
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  64 Current lambda_star [0.00468653] M= 480 N0= 213
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.11
# ==== sampling cov params====
# BG self.iteration= 64
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  65 Current lambda_star [0.00458492] M= 495 N0= 227
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.2
# ==== sampling cov params====
# BG self.iteration= 65
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  66 Current lambda_star [0.00451309] M= 500 N0= 217
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.13
# ==== sampling cov params====
# BG self.iteration= 66
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  67 Current lambda_star [0.00426973] M= 467 N0= 205
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.11
# ==== sampling cov params====
# BG self.iteration= 67
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  68 Current lambda_star [0.0043883] M= 454 N0= 219
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.2
# ==== sampling cov params====
# BG self.iteration= 68
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  69 Current lambda_star [0.00460826] M= 463 N0= 210
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.09
# ==== sampling cov params====
# BG self.iteration= 69
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  70 Current lambda_star [0.00463614] M= 425 N0= 223
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.13
# ==== sampling cov params====
# BG self.iteration= 70
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  71 Current lambda_star [0.00453425] M= 455 N0= 236
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.12
# ==== sampling cov params====
# BG self.iteration= 71
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  72 Current lambda_star [0.00466511] M= 493 N0= 211
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.15
# ==== sampling cov params====
# BG self.iteration= 72
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  73 Current lambda_star [0.00451423] M= 425 N0= 225
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.14
# ==== sampling cov params====
# BG self.iteration= 73
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  74 Current lambda_star [0.00462476] M= 473 N0= 224
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.03
# ==== sampling cov params====
# BG self.iteration= 74
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  75 Current lambda_star [0.00495089] M= 498 N0= 219
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.11
# ==== sampling cov params====
# BG self.iteration= 75
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  76 Current lambda_star [0.00518753] M= 529 N0= 218
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.13
# ==== sampling cov params====
# BG self.iteration= 76
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  77 Current lambda_star [0.00518611] M= 551 N0= 216
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.18
# ==== sampling cov params====
# BG self.iteration= 77
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  78 Current lambda_star [0.00544614] M= 574 N0= 217
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.17
# ==== sampling cov params====
# BG self.iteration= 78
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  79 Current lambda_star [0.00529766] M= 546 N0= 223
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.18
# ==== sampling cov params====
# BG self.iteration= 79
# cov params= [array([5.05610994]), array([0.37832166, 0.38424219])]
# iter=  80 Current lambda_star [0.00495588] M= 550 N0= 223
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.17
# ==== sampling cov params====
# BG self.iteration= 80
# cov params= [array([4.86548787]), array([0.37637242, 0.39289994])]
# iter=  81 Current lambda_star [0.00538421] M= 553 N0= 230
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.15
# ==== sampling cov params====
# BG self.iteration= 81
# cov params= [array([4.86548787]), array([0.37637242, 0.39289994])]
# iter=  82 Current lambda_star [0.00500304] M= 518 N0= 227
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.16
# ==== sampling cov params====
# BG self.iteration= 82
# cov params= [array([4.86548787]), array([0.37637242, 0.39289994])]
# iter=  83 Current lambda_star [0.0050624] M= 534 N0= 225
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.23
# ==== sampling cov params====
# BG self.iteration= 83
# cov params= [array([4.78881019]), array([0.38416517, 0.38224501])]
# iter=  84 Current lambda_star [0.00510397] M= 525 N0= 215
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.19
# ==== sampling cov params====
# BG self.iteration= 84
# cov params= [array([4.78881019]), array([0.38416517, 0.38224501])]
# iter=  85 Current lambda_star [0.00508371] M= 528 N0= 222
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.12
# ==== sampling cov params====
# BG self.iteration= 85
# cov params= [array([4.78881019]), array([0.38416517, 0.38224501])]
# iter=  86 Current lambda_star [0.00496125] M= 521 N0= 220
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.16
# ==== sampling cov params====
# BG self.iteration= 86
# cov params= [array([4.78881019]), array([0.38416517, 0.38224501])]
# iter=  87 Current lambda_star [0.0050539] M= 490 N0= 224
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.25
# ==== sampling cov params====
# BG self.iteration= 87
# cov params= [array([4.78881019]), array([0.38416517, 0.38224501])]
# iter=  88 Current lambda_star [0.00466579] M= 493 N0= 222
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.3
# ==== sampling cov params====
# BG self.iteration= 88
# cov params= [array([4.78881019]), array([0.38416517, 0.38224501])]
# iter=  89 Current lambda_star [0.00459064] M= 467 N0= 220
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.13
# ==== sampling cov params====
# BG self.iteration= 89
# cov params= [array([4.78881019]), array([0.38416517, 0.38224501])]
# iter=  90 Current lambda_star [0.00481325] M= 478 N0= 218
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.14
# ==== sampling cov params====
# BG self.iteration= 90
# cov params= [array([4.7483343]), array([0.38835978, 0.38335621])]
# iter=  91 Current lambda_star [0.0049917] M= 530 N0= 215
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.09
# ==== sampling cov params====
# BG self.iteration= 91
# cov params= [array([4.7483343]), array([0.38835978, 0.38335621])]
# iter=  92 Current lambda_star [0.00494187] M= 500 N0= 213
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.06
# ==== sampling cov params====
# BG self.iteration= 92
# cov params= [array([4.7483343]), array([0.38835978, 0.38335621])]
# iter=  93 Current lambda_star [0.00504881] M= 484 N0= 222
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.15
# ==== sampling cov params====
# BG self.iteration= 93
# cov params= [array([5.02410057]), array([0.39275987, 0.38679669])]
# iter=  94 Current lambda_star [0.00492835] M= 519 N0= 221
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.23
# ==== sampling cov params====
# BG self.iteration= 94
# cov params= [array([5.02410057]), array([0.39275987, 0.38679669])]
# iter=  95 Current lambda_star [0.0047156] M= 504 N0= 226
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.19
# ==== sampling cov params====
# BG self.iteration= 95
# cov params= [array([5.02410057]), array([0.39275987, 0.38679669])]
# iter=  96 Current lambda_star [0.00529632] M= 520 N0= 224
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.07
# ==== sampling cov params====
# BG self.iteration= 96
# cov params= [array([5.02410057]), array([0.39275987, 0.38679669])]
# iter=  97 Current lambda_star [0.00500482] M= 548 N0= 224
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.1
# ==== sampling cov params====
# BG self.iteration= 97
# cov params= [array([5.02410057]), array([0.39275987, 0.38679669])]
# iter=  98 Current lambda_star [0.00525654] M= 508 N0= 217
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.13
# ==== sampling cov params====
# BG self.iteration= 98
# cov params= [array([5.02410057]), array([0.39275987, 0.38679669])]
# iter=  99 Current lambda_star [0.00509372] M= 530 N0= 228
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.13
# ==== sampling cov params====
# BG self.iteration= 99
# cov params= [array([5.02410057]), array([0.39275987, 0.38679669])]
# iter=  100 Current lambda_star [0.00496938] M= 536 N0= 211
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.18
# ==== sampling cov params====
# BG self.iteration= 100
# cov params= [array([5.02410057]), array([0.39275987, 0.38679669])]
# iter=  101 Current lambda_star [0.00529991] M= 532 N0= 213
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.09
# ==== sampling cov params====
# BG self.iteration= 101
# cov params= [array([5.02410057]), array([0.39275987, 0.38679669])]
# iter=  102 Current lambda_star [0.00481219] M= 525 N0= 212
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.13
# ==== sampling cov params====
# BG self.iteration= 102
# cov params= [array([5.02410057]), array([0.39275987, 0.38679669])]
# iter=  103 Current lambda_star [0.00478494] M= 518 N0= 212
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.08
# ==== sampling cov params====
# BG self.iteration= 103
# cov params= [array([5.02410057]), array([0.39275987, 0.38679669])]
# iter=  104 Current lambda_star [0.00471714] M= 491 N0= 210
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.21
# ==== sampling cov params====
# BG self.iteration= 104
# cov params= [array([5.02410057]), array([0.39275987, 0.38679669])]
# iter=  105 Current lambda_star [0.00405552] M= 467 N0= 204
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.13
# ==== sampling cov params====
# BG self.iteration= 105
# cov params= [array([5.02410057]), array([0.39275987, 0.38679669])]
# iter=  106 Current lambda_star [0.00422911] M= 433 N0= 201
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.15
# ==== sampling cov params====
# BG self.iteration= 106
# cov params= [array([5.02410057]), array([0.39275987, 0.38679669])]
# iter=  107 Current lambda_star [0.00486551] M= 472 N0= 211
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.12
# ==== sampling cov params====
# BG self.iteration= 107
# cov params= [array([4.65026037]), array([0.37793971, 0.3850198 ])]
# iter=  108 Current lambda_star [0.00497871] M= 490 N0= 224
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.13
# ==== sampling cov params====
# BG self.iteration= 108
# cov params= [array([4.65026037]), array([0.37793971, 0.3850198 ])]
# iter=  109 Current lambda_star [0.00468072] M= 470 N0= 215
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.07
# ==== sampling cov params====
# BG self.iteration= 109
# cov params= [array([4.65026037]), array([0.37793971, 0.3850198 ])]
# iter=  110 Current lambda_star [0.00454385] M= 436 N0= 224
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.24
# ==== sampling cov params====
# BG self.iteration= 110
# cov params= [array([4.65026037]), array([0.37793971, 0.3850198 ])]
# current M= 437
# iter=  111 Current lambda_star [0.00438934] M= 437 N0= 213
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.13
# ==== sampling cov params====
# BG self.iteration= 111
# cov params= [array([4.65026037]), array([0.37793971, 0.3850198 ])]
# iter=  112 Current lambda_star [0.00428061] M= 437 N0= 218
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.09
# ==== sampling cov params====
# BG self.iteration= 112
# cov params= [array([4.65026037]), array([0.37793971, 0.3850198 ])]
# iter=  113 Current lambda_star [0.00463293] M= 434 N0= 210
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.1
# ==== sampling cov params====
# BG self.iteration= 113
# cov params= [array([4.65026037]), array([0.37793971, 0.3850198 ])]
# iter=  114 Current lambda_star [0.00470152] M= 481 N0= 208
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.06
# ==== sampling cov params====
# BG self.iteration= 114
# cov params= [array([4.65026037]), array([0.37793971, 0.3850198 ])]
# iter=  115 Current lambda_star [0.00483186] M= 458 N0= 206
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.19
# ==== sampling cov params====
# BG self.iteration= 115
# cov params= [array([4.65026037]), array([0.37793971, 0.3850198 ])]
# iter=  116 Current lambda_star [0.00503826] M= 510 N0= 211
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.12
# ==== sampling cov params====
# BG self.iteration= 116
# cov params= [array([4.65026037]), array([0.37793971, 0.3850198 ])]
# iter=  117 Current lambda_star [0.00479979] M= 492 N0= 208
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.19
# ==== sampling cov params====
# BG self.iteration= 117
# cov params= [array([4.65026037]), array([0.37793971, 0.3850198 ])]
# iter=  118 Current lambda_star [0.00461944] M= 451 N0= 214
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.17
# ==== sampling cov params====
# BG self.iteration= 118
# cov params= [array([4.65026037]), array([0.37793971, 0.3850198 ])]
# iter=  119 Current lambda_star [0.00482442] M= 473 N0= 204
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.12
# ==== sampling cov params====
# BG self.iteration= 119
# cov params= [array([4.65026037]), array([0.37793971, 0.3850198 ])]
# iter=  120 Current lambda_star [0.00485979] M= 546 N0= 214
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.11
# ==== sampling cov params====
# BG self.iteration= 120
# cov params= [array([4.65026037]), array([0.37793971, 0.3850198 ])]
# current M= 500
# iter=  121 Current lambda_star [0.00485229] M= 500 N0= 215
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.2
# ==== sampling cov params====
# BG self.iteration= 121
# cov params= [array([4.65026037]), array([0.37793971, 0.3850198 ])]
# iter=  122 Current lambda_star [0.00466109] M= 494 N0= 223
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.17
# ==== sampling cov params====
# BG self.iteration= 122
# cov params= [array([4.65026037]), array([0.37793971, 0.3850198 ])]
# iter=  123 Current lambda_star [0.00479189] M= 503 N0= 212
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.14
# ==== sampling cov params====
# BG self.iteration= 123
# cov params= [array([4.65026037]), array([0.37793971, 0.3850198 ])]
# iter=  124 Current lambda_star [0.00462609] M= 488 N0= 212
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.08
# ==== sampling cov params====
# BG self.iteration= 124
# cov params= [array([4.65026037]), array([0.37793971, 0.3850198 ])]
# iter=  125 Current lambda_star [0.00455772] M= 467 N0= 202
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.12
# ==== sampling cov params====
# BG self.iteration= 125
# cov params= [array([4.65026037]), array([0.37793971, 0.3850198 ])]
# iter=  126 Current lambda_star [0.00451084] M= 469 N0= 207
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.08
# ==== sampling cov params====
# BG self.iteration= 126
# cov params= [array([4.65026037]), array([0.37793971, 0.3850198 ])]
# iter=  127 Current lambda_star [0.00473686] M= 480 N0= 220
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.14
# ==== sampling cov params====
# BG self.iteration= 127
# cov params= [array([4.65026037]), array([0.37793971, 0.3850198 ])]
# iter=  128 Current lambda_star [0.00446902] M= 472 N0= 204
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.21
# ==== sampling cov params====
# BG self.iteration= 128
# cov params= [array([4.65026037]), array([0.37793971, 0.3850198 ])]
# iter=  129 Current lambda_star [0.00483346] M= 509 N0= 213
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.21
# ==== sampling cov params====
# BG self.iteration= 129
# cov params= [array([4.65026037]), array([0.37793971, 0.3850198 ])]
# iter=  130 Current lambda_star [0.00498271] M= 548 N0= 199
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.12
# ==== sampling cov params====
# BG self.iteration= 130
# cov params= [array([4.49817973]), array([0.37961406, 0.372438  ])]
# current M= 527
# iter=  131 Current lambda_star [0.00513294] M= 527 N0= 198
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.18
# ==== sampling cov params====
# BG self.iteration= 131
# cov params= [array([4.49817973]), array([0.37961406, 0.372438  ])]
# iter=  132 Current lambda_star [0.00493368] M= 502 N0= 213
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.13
# ==== sampling cov params====
# BG self.iteration= 132
# cov params= [array([4.49817973]), array([0.37961406, 0.372438  ])]
# iter=  133 Current lambda_star [0.00512707] M= 508 N0= 219
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.2
# ==== sampling cov params====
# BG self.iteration= 133
# cov params= [array([4.49817973]), array([0.37961406, 0.372438  ])]
# iter=  134 Current lambda_star [0.0045525] M= 498 N0= 224
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.11
# ==== sampling cov params====
# BG self.iteration= 134
# cov params= [array([4.49817973]), array([0.37961406, 0.372438  ])]
# iter=  135 Current lambda_star [0.00488058] M= 486 N0= 198
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.09
# ==== sampling cov params====
# BG self.iteration= 135
# cov params= [array([4.49817973]), array([0.37961406, 0.372438  ])]
# iter=  136 Current lambda_star [0.00505804] M= 509 N0= 215
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.14
# ==== sampling cov params====
# BG self.iteration= 136
# cov params= [array([4.49817973]), array([0.37961406, 0.372438  ])]
# iter=  137 Current lambda_star [0.005402] M= 562 N0= 211
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.22
# ==== sampling cov params====
# BG self.iteration= 137
# cov params= [array([4.49817973]), array([0.37961406, 0.372438  ])]
# iter=  138 Current lambda_star [0.00526904] M= 563 N0= 233
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.25
# ==== sampling cov params====
# BG self.iteration= 138
# cov params= [array([4.49817973]), array([0.37961406, 0.372438  ])]
# iter=  139 Current lambda_star [0.00520996] M= 538 N0= 213
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.15
# ==== sampling cov params====
# BG self.iteration= 139
# cov params= [array([4.49817973]), array([0.37961406, 0.372438  ])]
# iter=  140 Current lambda_star [0.0058567] M= 615 N0= 220
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.17
# ==== sampling cov params====
# BG self.iteration= 140
# cov params= [array([4.49817973]), array([0.37961406, 0.372438  ])]
# current M= 603
# iter=  141 Current lambda_star [0.00553371] M= 603 N0= 216
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.07
# ==== sampling cov params====
# BG self.iteration= 141
# cov params= [array([4.49817973]), array([0.37961406, 0.372438  ])]
# iter=  142 Current lambda_star [0.00507318] M= 556 N0= 217
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.2
# ==== sampling cov params====
# BG self.iteration= 142
# cov params= [array([4.49817973]), array([0.37961406, 0.372438  ])]
# iter=  143 Current lambda_star [0.00494951] M= 539 N0= 212
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.21
# ==== sampling cov params====
# BG self.iteration= 143
# cov params= [array([4.49817973]), array([0.37961406, 0.372438  ])]
# iter=  144 Current lambda_star [0.00508553] M= 546 N0= 213
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.16
# ==== sampling cov params====
# BG self.iteration= 144
# cov params= [array([4.49817973]), array([0.37961406, 0.372438  ])]
# iter=  145 Current lambda_star [0.00481695] M= 522 N0= 217
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.19
# ==== sampling cov params====
# BG self.iteration= 145
# cov params= [array([4.49817973]), array([0.37961406, 0.372438  ])]
# iter=  146 Current lambda_star [0.00477728] M= 499 N0= 205
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.15
# ==== sampling cov params====
# BG self.iteration= 146
# cov params= [array([4.49817973]), array([0.37961406, 0.372438  ])]
# iter=  147 Current lambda_star [0.00501084] M= 487 N0= 217
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.08
# ==== sampling cov params====
# BG self.iteration= 147
# cov params= [array([4.49817973]), array([0.37961406, 0.372438  ])]
# iter=  148 Current lambda_star [0.00530866] M= 544 N0= 215
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.19
# ==== sampling cov params====
# BG self.iteration= 148
# cov params= [array([4.49817973]), array([0.37961406, 0.372438  ])]
# iter=  149 Current lambda_star [0.00484787] M= 516 N0= 223
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.07
# ==== sampling cov params====
# BG self.iteration= 149
# cov params= [array([4.2580568]), array([0.38994397, 0.37733825])]
# iter=  150 Current lambda_star [0.00465678] M= 461 N0= 211
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.05
# ==== sampling cov params====
# BG self.iteration= 150
# cov params= [array([4.2580568]), array([0.38994397, 0.37733825])]
# current M= 472
# iter=  151 Current lambda_star [0.0046375] M= 472 N0= 211
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.08
# ==== sampling cov params====
# BG self.iteration= 151
# cov params= [array([4.2580568]), array([0.38994397, 0.37733825])]
# iter=  152 Current lambda_star [0.00501924] M= 525 N0= 217
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.12
# ==== sampling cov params====
# BG self.iteration= 152
# cov params= [array([4.2580568]), array([0.38994397, 0.37733825])]
# iter=  153 Current lambda_star [0.00498951] M= 507 N0= 222
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.15
# ==== sampling cov params====
# BG self.iteration= 153
# cov params= [array([4.2580568]), array([0.38994397, 0.37733825])]
# iter=  154 Current lambda_star [0.00488695] M= 490 N0= 213
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.1
# ==== sampling cov params====
# BG self.iteration= 154
# cov params= [array([4.2580568]), array([0.38994397, 0.37733825])]
# iter=  155 Current lambda_star [0.00538721] M= 533 N0= 226
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.14
# ==== sampling cov params====
# BG self.iteration= 155
# cov params= [array([4.2580568]), array([0.38994397, 0.37733825])]
# iter=  156 Current lambda_star [0.00546785] M= 544 N0= 219
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.14
# ==== sampling cov params====
# BG self.iteration= 156
# cov params= [array([4.2580568]), array([0.38994397, 0.37733825])]
# iter=  157 Current lambda_star [0.00502325] M= 557 N0= 225
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.16
# ==== sampling cov params====
# BG self.iteration= 157
# cov params= [array([4.2580568]), array([0.38994397, 0.37733825])]
# iter=  158 Current lambda_star [0.0046202] M= 477 N0= 223
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.16
# ==== sampling cov params====
# BG self.iteration= 158
# cov params= [array([4.2580568]), array([0.38994397, 0.37733825])]
# iter=  159 Current lambda_star [0.0042425] M= 432 N0= 210
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.1
# ==== sampling cov params====
# BG self.iteration= 159
# cov params= [array([4.2580568]), array([0.38994397, 0.37733825])]
# iter=  160 Current lambda_star [0.00394335] M= 374 N0= 218
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.15
# ==== sampling cov params====
# BG self.iteration= 160
# cov params= [array([4.2580568]), array([0.38994397, 0.37733825])]
# current M= 382
# iter=  161 Current lambda_star [0.00402942] M= 382 N0= 208
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.13
# ==== sampling cov params====
# BG self.iteration= 161
# cov params= [array([4.2580568]), array([0.38994397, 0.37733825])]
# iter=  162 Current lambda_star [0.00396811] M= 385 N0= 221
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.05
# ==== sampling cov params====
# BG self.iteration= 162
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# iter=  163 Current lambda_star [0.00383157] M= 344 N0= 221
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.1
# ==== sampling cov params====
# BG self.iteration= 163
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# iter=  164 Current lambda_star [0.00416434] M= 355 N0= 208
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.13
# ==== sampling cov params====
# BG self.iteration= 164
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# iter=  165 Current lambda_star [0.0045714] M= 389 N0= 218
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.17
# ==== sampling cov params====
# BG self.iteration= 165
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# iter=  166 Current lambda_star [0.00502595] M= 486 N0= 216
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.2
# ==== sampling cov params====
# BG self.iteration= 166
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# iter=  167 Current lambda_star [0.00506304] M= 503 N0= 219
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.11
# ==== sampling cov params====
# BG self.iteration= 167
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# iter=  168 Current lambda_star [0.005005] M= 515 N0= 224
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.13
# ==== sampling cov params====
# BG self.iteration= 168
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# iter=  169 Current lambda_star [0.00510746] M= 493 N0= 212
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.06
# ==== sampling cov params====
# BG self.iteration= 169
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# iter=  170 Current lambda_star [0.00533862] M= 553 N0= 216
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.2
# ==== sampling cov params====
# BG self.iteration= 170
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# current M= 609
# iter=  171 Current lambda_star [0.00569602] M= 609 N0= 223
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.13
# ==== sampling cov params====
# BG self.iteration= 171
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# iter=  172 Current lambda_star [0.0057118] M= 595 N0= 219
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.08
# ==== sampling cov params====
# BG self.iteration= 172
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# iter=  173 Current lambda_star [0.00614655] M= 650 N0= 222
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.16
# ==== sampling cov params====
# BG self.iteration= 173
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# iter=  174 Current lambda_star [0.00605944] M= 634 N0= 227
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.11
# ==== sampling cov params====
# BG self.iteration= 174
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# iter=  175 Current lambda_star [0.00571421] M= 585 N0= 225
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.09
# ==== sampling cov params====
# BG self.iteration= 175
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# iter=  176 Current lambda_star [0.00588156] M= 623 N0= 222
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.15
# ==== sampling cov params====
# BG self.iteration= 176
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# iter=  177 Current lambda_star [0.00613763] M= 644 N0= 216
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.13
# ==== sampling cov params====
# BG self.iteration= 177
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# iter=  178 Current lambda_star [0.00634497] M= 701 N0= 208
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.15
# ==== sampling cov params====
# BG self.iteration= 178
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# iter=  179 Current lambda_star [0.00595044] M= 688 N0= 224
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.13
# ==== sampling cov params====
# BG self.iteration= 179
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# iter=  180 Current lambda_star [0.00590287] M= 603 N0= 212
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.12
# ==== sampling cov params====
# BG self.iteration= 180
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# current M= 630
# iter=  181 Current lambda_star [0.00592747] M= 630 N0= 229
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.1
# ==== sampling cov params====
# BG self.iteration= 181
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# iter=  182 Current lambda_star [0.00595298] M= 629 N0= 208
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.15
# ==== sampling cov params====
# BG self.iteration= 182
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# iter=  183 Current lambda_star [0.00643155] M= 693 N0= 228
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.23
# ==== sampling cov params====
# BG self.iteration= 183
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# iter=  184 Current lambda_star [0.00625404] M= 721 N0= 230
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.18
# ==== sampling cov params====
# BG self.iteration= 184
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# iter=  185 Current lambda_star [0.00594264] M= 659 N0= 230
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.2
# ==== sampling cov params====
# BG self.iteration= 185
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# iter=  186 Current lambda_star [0.00656496] M= 658 N0= 230
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.1
# ==== sampling cov params====
# BG self.iteration= 186
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# iter=  187 Current lambda_star [0.00640156] M= 704 N0= 227
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.2
# ==== sampling cov params====
# BG self.iteration= 187
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# iter=  188 Current lambda_star [0.00632997] M= 704 N0= 215
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.12
# ==== sampling cov params====
# BG self.iteration= 188
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# iter=  189 Current lambda_star [0.00600158] M= 648 N0= 231
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.23
# ==== sampling cov params====
# BG self.iteration= 189
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# iter=  190 Current lambda_star [0.00544277] M= 634 N0= 220
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.18
# ==== sampling cov params====
# BG self.iteration= 190
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# current M= 589
# iter=  191 Current lambda_star [0.0055742] M= 589 N0= 217
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.12
# ==== sampling cov params====
# BG self.iteration= 191
# cov params= [array([4.35796977]), array([0.40378478, 0.36231859])]
# iter=  192 Current lambda_star [0.00529798] M= 596 N0= 222
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.11
# ==== sampling cov params====
# BG self.iteration= 192
# cov params= [array([4.21276507]), array([0.40363419, 0.362769  ])]
# iter=  193 Current lambda_star [0.0056011] M= 606 N0= 222
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.11
# ==== sampling cov params====
# BG self.iteration= 193
# cov params= [array([4.21276507]), array([0.40363419, 0.362769  ])]
# iter=  194 Current lambda_star [0.00508834] M= 562 N0= 211
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.08
# ==== sampling cov params====
# BG self.iteration= 194
# cov params= [array([4.21276507]), array([0.40363419, 0.362769  ])]
# iter=  195 Current lambda_star [0.00565514] M= 565 N0= 220
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.06
# ==== sampling cov params====
# BG self.iteration= 195
# cov params= [array([4.21276507]), array([0.40363419, 0.362769  ])]
# iter=  196 Current lambda_star [0.00531207] M= 553 N0= 214
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.11
# ...
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.2
# ==== sampling cov params====
# BG self.iteration= 966
# cov params= [array([12.57011795]), array([0.44977487, 0.43282664])]
# iter=  967 Current lambda_star [0.00494049] M= 522 N0= 222
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.17
# ==== sampling cov params====
# BG self.iteration= 967
# cov params= [array([12.57011795]), array([0.44977487, 0.43282664])]
# iter=  968 Current lambda_star [0.00511275] M= 525 N0= 223
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.12
# ==== sampling cov params====
# BG self.iteration= 968
# cov params= [array([12.80636826]), array([0.44876086, 0.43125875])]
# iter=  969 Current lambda_star [0.00497851] M= 530 N0= 223
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.33
# ==== sampling cov params====
# BG self.iteration= 969
# cov params= [array([12.80636826]), array([0.44876086, 0.43125875])]
# iter=  970 Current lambda_star [0.00562378] M= 573 N0= 226
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.25
# ==== sampling cov params====
# BG self.iteration= 970
# cov params= [array([12.80636826]), array([0.44876086, 0.43125875])]
# current M= 576
# iter=  971 Current lambda_star [0.00553228] M= 576 N0= 215
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.22
# ==== sampling cov params====
# BG self.iteration= 971
# cov params= [array([12.80636826]), array([0.44876086, 0.43125875])]
# iter=  972 Current lambda_star [0.00536577] M= 582 N0= 217
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.17
# ==== sampling cov params====
# BG self.iteration= 972
# cov params= [array([12.80636826]), array([0.44876086, 0.43125875])]
# iter=  973 Current lambda_star [0.00532051] M= 580 N0= 218
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.14
# ==== sampling cov params====
# BG self.iteration= 973
# cov params= [array([12.80636826]), array([0.44876086, 0.43125875])]
# iter=  974 Current lambda_star [0.00544782] M= 603 N0= 219
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.2
# ==== sampling cov params====
# BG self.iteration= 974
# cov params= [array([12.80636826]), array([0.44876086, 0.43125875])]
# iter=  975 Current lambda_star [0.00558287] M= 590 N0= 226
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.2
# ==== sampling cov params====
# BG self.iteration= 975
# cov params= [array([12.80636826]), array([0.44876086, 0.43125875])]
# iter=  976 Current lambda_star [0.00520422] M= 543 N0= 230
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.2
# ==== sampling cov params====
# BG self.iteration= 976
# cov params= [array([12.80636826]), array([0.44876086, 0.43125875])]
# iter=  977 Current lambda_star [0.0058161] M= 574 N0= 230
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.2
# ==== sampling cov params====
# BG self.iteration= 977
# cov params= [array([12.80636826]), array([0.44876086, 0.43125875])]
# iter=  978 Current lambda_star [0.00588387] M= 621 N0= 228
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.16
# ==== sampling cov params====
# BG self.iteration= 978
# cov params= [array([12.80636826]), array([0.44876086, 0.43125875])]
# iter=  979 Current lambda_star [0.00588701] M= 659 N0= 228
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.18
# ==== sampling cov params====
# BG self.iteration= 979
# cov params= [array([12.80636826]), array([0.44876086, 0.43125875])]
# iter=  980 Current lambda_star [0.00631889] M= 673 N0= 221
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.25
# ==== sampling cov params====
# BG self.iteration= 980
# cov params= [array([14.10688153]), array([0.45149461, 0.43781385])]
# current M= 663
# iter=  981 Current lambda_star [0.00618446] M= 663 N0= 241
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.26
# ==== sampling cov params====
# BG self.iteration= 981
# cov params= [array([14.10688153]), array([0.45149461, 0.43781385])]
# iter=  982 Current lambda_star [0.00605603] M= 662 N0= 235
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.07
# ==== sampling cov params====
# BG self.iteration= 982
# cov params= [array([14.10688153]), array([0.45149461, 0.43781385])]
# iter=  983 Current lambda_star [0.00556238] M= 683 N0= 217
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.28
# ==== sampling cov params====
# BG self.iteration= 983
# cov params= [array([14.10688153]), array([0.45149461, 0.43781385])]
# iter=  984 Current lambda_star [0.00573727] M= 614 N0= 220
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.18
# ==== sampling cov params====
# BG self.iteration= 984
# cov params= [array([14.10688153]), array([0.45149461, 0.43781385])]
# iter=  985 Current lambda_star [0.00607831] M= 642 N0= 229
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.11
# ==== sampling cov params====
# BG self.iteration= 985
# cov params= [array([14.10688153]), array([0.45149461, 0.43781385])]
# iter=  986 Current lambda_star [0.0064307] M= 701 N0= 219
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.15
# ==== sampling cov params====
# BG self.iteration= 986
# cov params= [array([14.10688153]), array([0.45149461, 0.43781385])]
# iter=  987 Current lambda_star [0.00607838] M= 690 N0= 229
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.25
# ==== sampling cov params====
# BG self.iteration= 987
# cov params= [array([14.10688153]), array([0.45149461, 0.43781385])]
# iter=  988 Current lambda_star [0.00555995] M= 653 N0= 230
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.24
# ==== sampling cov params====
# BG self.iteration= 988
# cov params= [array([14.10688153]), array([0.45149461, 0.43781385])]
# iter=  989 Current lambda_star [0.00546817] M= 600 N0= 232
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.24
# ==== sampling cov params====
# BG self.iteration= 989
# cov params= [array([14.10688153]), array([0.45149461, 0.43781385])]
# iter=  990 Current lambda_star [0.00555834] M= 616 N0= 228
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.16
# ==== sampling cov params====
# BG self.iteration= 990
# cov params= [array([14.10688153]), array([0.45149461, 0.43781385])]
# current M= 583
# iter=  991 Current lambda_star [0.00539849] M= 583 N0= 223
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.12
# ==== sampling cov params====
# BG self.iteration= 991
# cov params= [array([14.10688153]), array([0.45149461, 0.43781385])]
# iter=  992 Current lambda_star [0.00525995] M= 589 N0= 229
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.18
# ==== sampling cov params====
# BG self.iteration= 992
# cov params= [array([14.10688153]), array([0.45149461, 0.43781385])]
# iter=  993 Current lambda_star [0.00520142] M= 524 N0= 220
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.17
# ==== sampling cov params====
# BG self.iteration= 993
# cov params= [array([14.10688153]), array([0.45149461, 0.43781385])]
# iter=  994 Current lambda_star [0.00536828] M= 581 N0= 225
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.12
# ==== sampling cov params====
# BG self.iteration= 994
# cov params= [array([14.10688153]), array([0.45149461, 0.43781385])]
# iter=  995 Current lambda_star [0.00577004] M= 596 N0= 210
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.13
# ==== sampling cov params====
# BG self.iteration= 995
# cov params= [array([14.10688153]), array([0.45149461, 0.43781385])]
# iter=  996 Current lambda_star [0.00636396] M= 669 N0= 218
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.21
# ==== sampling cov params====
# BG self.iteration= 996
# cov params= [array([14.10688153]), array([0.45149461, 0.43781385])]
# iter=  997 Current lambda_star [0.00699257] M= 763 N0= 223
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.15
# ==== sampling cov params====
# BG self.iteration= 997
# cov params= [array([13.80848799]), array([0.45426418, 0.43435275])]
# iter=  998 Current lambda_star [0.0065403] M= 771 N0= 233
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.18
# ==== sampling cov params====
# BG self.iteration= 998
# cov params= [array([13.80848799]), array([0.45426418, 0.43435275])]
# iter=  999 Current lambda_star [0.00655442] M= 792 N0= 214
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.13
# ==== sampling cov params====
# BG self.iteration= 999
# cov params= [array([13.80848799]), array([0.45426418, 0.43435275])]
# iter=  1000 Current lambda_star [0.00641441] M= 739 N0= 224
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.08
# ==== sampling cov params====
# BG self.iteration= 1000
# cov params= [array([13.80848799]), array([0.45426418, 0.43435275])]
# current M= 778
# iter=  1001 Current lambda_star [0.00675788] M= 778 N0= 220
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.09
# ==== sampling cov params====
# BG self.iteration= 1001
# cov params= [array([13.80848799]), array([0.45426418, 0.43435275])]
# iter=  1002 Current lambda_star [0.00653126] M= 765 N0= 229
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.09
# ==== sampling cov params====
# BG self.iteration= 1002
# cov params= [array([13.80848799]), array([0.45426418, 0.43435275])]
# iter=  1003 Current lambda_star [0.00623825] M= 706 N0= 218
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.23
# ==== sampling cov params====
# BG self.iteration= 1003
# cov params= [array([13.80848799]), array([0.45426418, 0.43435275])]
# iter=  1004 Current lambda_star [0.00665112] M= 696 N0= 229
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.25
# ==== sampling cov params====
# BG self.iteration= 1004
# cov params= [array([13.80848799]), array([0.45426418, 0.43435275])]
# iter=  1005 Current lambda_star [0.00636723] M= 710 N0= 227
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.16
# ==== sampling cov params====
# BG self.iteration= 1005
# cov params= [array([13.80848799]), array([0.45426418, 0.43435275])]
# iter=  1006 Current lambda_star [0.00666793] M= 734 N0= 224
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.2
# ==== sampling cov params====
# BG self.iteration= 1006
# cov params= [array([13.80848799]), array([0.45426418, 0.43435275])]
# iter=  1007 Current lambda_star [0.00640179] M= 725 N0= 227
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.23
# ==== sampling cov params====
# BG self.iteration= 1007
# cov params= [array([13.80848799]), array([0.45426418, 0.43435275])]
# iter=  1008 Current lambda_star [0.0062635] M= 708 N0= 221
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.19
# ==== sampling cov params====
# BG self.iteration= 1008
# cov params= [array([13.80848799]), array([0.45426418, 0.43435275])]
# iter=  1009 Current lambda_star [0.00620209] M= 713 N0= 217
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.2
# ==== sampling cov params====
# BG self.iteration= 1009
# cov params= [array([13.80848799]), array([0.45426418, 0.43435275])]
# iter=  1010 Current lambda_star [0.00597159] M= 663 N0= 219
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.23
# ==== sampling cov params====
# BG self.iteration= 1010
# cov params= [array([13.80848799]), array([0.45426418, 0.43435275])]
# current M= 689
# iter=  1011 Current lambda_star [0.00593112] M= 689 N0= 225
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.1
# ==== sampling cov params====
# BG self.iteration= 1011
# cov params= [array([13.80848799]), array([0.45426418, 0.43435275])]
# iter=  1012 Current lambda_star [0.00584683] M= 669 N0= 212
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.16
# ==== sampling cov params====
# BG self.iteration= 1012
# cov params= [array([13.39747679]), array([0.45364374, 0.42904481])]
# iter=  1013 Current lambda_star [0.005455] M= 656 N0= 219
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.28
# ==== sampling cov params====
# BG self.iteration= 1013
# cov params= [array([13.39747679]), array([0.45364374, 0.42904481])]
# iter=  1014 Current lambda_star [0.00543785] M= 627 N0= 218
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.16
# ==== sampling cov params====
# BG self.iteration= 1014
# cov params= [array([13.39747679]), array([0.45364374, 0.42904481])]
# iter=  1015 Current lambda_star [0.00539021] M= 613 N0= 220
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.16
# ==== sampling cov params====
# BG self.iteration= 1015
# cov params= [array([13.39747679]), array([0.45364374, 0.42904481])]
# iter=  1016 Current lambda_star [0.00566066] M= 614 N0= 218
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.23
# ==== sampling cov params====
# BG self.iteration= 1016
# cov params= [array([13.39747679]), array([0.45364374, 0.42904481])]
# iter=  1017 Current lambda_star [0.00539764] M= 587 N0= 221
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.18
# ==== sampling cov params====
# BG self.iteration= 1017
# cov params= [array([13.39747679]), array([0.45364374, 0.42904481])]
# iter=  1018 Current lambda_star [0.00576025] M= 618 N0= 230
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.19
# ==== sampling cov params====
# BG self.iteration= 1018
# cov params= [array([13.39747679]), array([0.45364374, 0.42904481])]
# iter=  1019 Current lambda_star [0.00537789] M= 601 N0= 209
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.18
# ==== sampling cov params====
# BG self.iteration= 1019
# cov params= [array([13.39747679]), array([0.45364374, 0.42904481])]
# iter=  1020 Current lambda_star [0.00519053] M= 554 N0= 226
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.14
# ==== sampling cov params====
# BG self.iteration= 1020
# cov params= [array([13.39747679]), array([0.45364374, 0.42904481])]
# current M= 546
# iter=  1021 Current lambda_star [0.00525563] M= 546 N0= 227
# sigma proposal log units = 0.01 Nproposals= 100
# acc offspring= 0.23
# ==== sampling cov params====
# BG self.iteration= 1021
# cov params= [array([13.39747679]), array([0.45364374, 0.42904481])]
# iter=  1022 Current lambda_star [0.00450859] M= 521 N0= 217
# sigma proposal log units = 0.01 Nproposals= 100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 GS.sample()
#
# File /Volumes/data_SFB1294/pack/gpetas_github/gpetas/core/Gibbs_sampler.py:152, in GS_ETAS.sample(self)
#     150 while self.iteration < self.burnin + self.num_samples:
#     151     self.sample_branching_structure()
# --> 152     self.sample_offspring_parameters()
#     153     self.sample_background_intensity()
#     154     self.save_results_and_info()
#
# File /Volumes/data_SFB1294/pack/gpetas_github/gpetas/core/Gibbs_sampler.py:444, in GS_ETAS.sample_offspring_parameters(self)
#     442 l_k = self.calculate_log_likelihood(theta_k)
#     443 log_prior_k = self.evaluate_log_prior(theta_k)
# --> 444 l_k_star = self.calculate_log_likelihood(theta_k_star)
#     445 log_prior_k_star = self.evaluate_log_prior(theta_k_star)
#     447 # MH criterion
#     448 # MH_alpha = np.min([1., np.exp(l_k_star - l_k)])
#
# File /Volumes/data_SFB1294/pack/gpetas_github/gpetas/core/Gibbs_sampler.py:548, in GS_ETAS.calculate_log_likelihood(self, theta_k)
#     545     return -np.inf
#     547 for o_idx in offspring_idx:
# --> 548     z_i = np.int(self.branching[o_idx])  # z_i = j with j=1,... (starts at 1
#     549     # not at 0)
#     550     m_j = self.data.magnitudes[z_i - 1]
#
# File ~/opt/anaconda3/envs/gpetas_env/lib/python3.9/site-packages/numpy/__init__.py:287, in __getattr__(attr)
#     285     pass
#     286 else:
# --> 287     warnings.warn(msg, DeprecationWarning, stacklevel=2)
#     288     return val
#     290 # Importing Tester requires importing all of UnitTest which is not a
#     291 # cheap import Since it is mainly used in test suits, we lazy import it
#     292 # here to save on the order of 10 ms of import time for most users
#     293 #
#     294 # The previous way Tester was imported also had a side effect of adding
#     295 # the full `numpy.testing` namespace
#
# KeyboardInterrupt:

# %% [markdown]
# #### Plot summary
# You can directly plot a summary of the Bayesian inference or
# you can first do MLE and plot subsequently a summary with comparison

# %%
gpetase_GS_obj = GS.save_data
gpetas.summary.summary_gpetas(mle_obj=mle_obj)
